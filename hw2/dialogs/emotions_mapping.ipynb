# %%
import torch
import random
import numpy as np
import pandas as pd
from transformers import RobertaTokenizerFast, RobertaForSequenceClassification
from torch.utils.data import DataLoader
from collections import defaultdict
from tqdm import tqdm

# %%
def foo(x: str):
    res = x.strip("[]").split()
    return [r.strip("'") for r in res]

# %%
df = pd.read_csv("data/dialogs.csv")
df["emotion"] = 0
df["dialog"] = df["dialog"].fillna("")
df["movie_genres"] = df["movie_genres"].apply(foo)
df["movie_genres"] = df["movie_genres"].apply(lambda x: x[0] if x else [])
df = df[df["movie_genres"].apply(len) > 0].copy()
print(len(df))
df.head()
# Out:
# 303870
#   movieID  dialog_id                                             dialog  \
# 0      m0          0  Can we make this quick?  Roxanne Korrine and A...
# 1      m0          0  Well I thought we'd start with pronunciation i...
# 2      m0          0  Not the hacking and gagging and spitting part....
# 3      m0          0  Okay... then how 'bout we try out some French ...
# 4      m0          1  You're asking me out.  That's so cute. What's ...
#
#   speakers                 movie_title movie_genres  emoji
# 0   BIANCA  10 things i hate about you       comedy      0
# 1  CAMERON  10 things i hate about you       comedy      0
# 2   BIANCA  10 things i hate about you       comedy      0
# 3  CAMERON  10 things i hate about you       comedy      0
# 4   BIANCA  10 things i hate about you       comedy      0

# %%
max_replic_in_dialog_count = 10
max_dialog_count_per_genre = 2500
df = df.groupby("dialog_id").head(max_replic_in_dialog_count)
df = df.groupby("movie_genres").head(max_dialog_count_per_genre)
df = df.reset_index(drop=True)
df
# Out:
#       movieID  dialog_id                                             dialog  \
# 0          m0          0  Can we make this quick?  Roxanne Korrine and A...
# 1          m0          0  Well I thought we'd start with pronunciation i...
# 2          m0          0  Not the hacking and gagging and spitting part....
# 3          m0          0  Okay... then how 'bout we try out some French ...
# 4          m0          1  You're asking me out.  That's so cute. What's ...
# ...       ...        ...                                                ...
# 33987    m603      81438  I've decided not to open a practice here  I wa...
# 33988    m603      81439  That's new territory for us...but yes we can l...
# 33989    m603      81439  No tax shelters.  No funding.  I want to fund ...
# 33990    m603      81439  That would mean liquidating sizable amounts of...
# 33991    m603      81439           I plan on liquidating almost evetything.
#
#       speakers                 movie_title movie_genres  emoji
# 0       BIANCA  10 things i hate about you       comedy      0
# 1      CAMERON  10 things i hate about you       comedy      0
# 2       BIANCA  10 things i hate about you       comedy      0
# 3      CAMERON  10 things i hate about you       comedy      0
# 4       BIANCA  10 things i hate about you       comedy      0
# ...        ...                         ...          ...    ...
# 33987    ROWAN           the witching hour  documentary      0
# 33988     RYAN           the witching hour  documentary      0
# 33989    ROWAN           the witching hour  documentary      0
# 33990     RYAN           the witching hour  documentary      0
# 33991    ROWAN           the witching hour  documentary      0
#
# [33992 rows x 7 columns]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = RobertaTokenizerFast.from_pretrained("cardiffnlp/twitter-roberta-base-emotion", model_max_length=514)
model = RobertaForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-emotion")
model = model.to(device)
device
# Out:
# device(type='cuda')

# %%
index2emoji = model.config.id2label
emoji2index = model.config.label2id
print(index2emoji)
print(emoji2index)
# Out:
# {0: 'joy', 1: 'optimism', 2: 'anger', 3: 'sadness'}
# {'joy': 0, 'optimism': 1, 'anger': 2, 'sadness': 3}

# %%
class Dataset:
    def __init__(self, df):
        self.df = df
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        return row["dialog"]
    def __len__(self):
        return len(self.df)

# %%
model.eval()
batch_size = 128
dataset = Dataset(df)
loader = DataLoader(dataset, batch_size=batch_size)
for i, sentences in enumerate(tqdm(loader)):
    torch.cuda.empty_cache()
    start, end = i * batch_size, (i + 1) * batch_size
    tokens = tokenizer.batch_encode_plus(
        sentences, padding=True, truncation=True, 
        return_tensors="pt"
    )
    input_ids = tokens["input_ids"]
    input_ids = input_ids.to(device)
    with torch.no_grad():
        output = model(input_ids)
    logits = output.logits
    indexes = logits.argmax(axis=1)
    indexes = indexes.cpu().tolist()
    emoji = [index2emoji[index] for index in indexes]
    df.loc[start:end-1, "emotion"] = emoji
# Out:
# 100%|██████████| 266/266 [05:54<00:00,  1.33s/it]

# %%
df
# Out:
#       movieID  dialog_id                                             dialog  \
# 0          m0          0  Can we make this quick?  Roxanne Korrine and A...
# 1          m0          0  Well I thought we'd start with pronunciation i...
# 2          m0          0  Not the hacking and gagging and spitting part....
# 3          m0          0  Okay... then how 'bout we try out some French ...
# 4          m0          1  You're asking me out.  That's so cute. What's ...
# ...       ...        ...                                                ...
# 33987    m603      81438  I've decided not to open a practice here  I wa...
# 33988    m603      81439  That's new territory for us...but yes we can l...
# 33989    m603      81439  No tax shelters.  No funding.  I want to fund ...
# 33990    m603      81439  That would mean liquidating sizable amounts of...
# 33991    m603      81439           I plan on liquidating almost evetything.
#
#       speakers                 movie_title movie_genres   emotion
# 0       BIANCA  10 things i hate about you       comedy       joy
# 1      CAMERON  10 things i hate about you       comedy  optimism
# 2       BIANCA  10 things i hate about you       comedy       joy
# 3      CAMERON  10 things i hate about you       comedy  optimism
# 4       BIANCA  10 things i hate about you       comedy  optimism
# ...        ...                         ...          ...       ...
# 33987    ROWAN           the witching hour  documentary   sadness
# 33988     RYAN           the witching hour  documentary     anger
# 33989    ROWAN           the witching hour  documentary     anger
# 33990     RYAN           the witching hour  documentary       joy
# 33991    ROWAN           the witching hour  documentary       joy
#
# [33992 rows x 7 columns]

# %%
df.to_csv(f"data/dialogs_marked_{len(df)}.csv")
